# %%
import pandas as pd
import geopandas as gpd
import pyogrio
import fiona

# %%
file_path = 'C:/Users/조민규/Downloads/OneDrive_2024-08-21 (1)/'
file_name = 'H_HYDG_P'

gdf = gpd.read_file(f'{file_path}/{file_name}.shp')

# %%
gdf
# Out:
#             ID            면적  경계코드  \
# 0       관입 화성암  8.120620e+07     6
# 1  미고결 쇄설성 퇴적층  1.212509e+08     1
# 2          변성암  2.772762e+08     8
# 3     비다공질 화산암  2.084559e+08     4
# 4       쇄설성퇴적암  1.007683e+08     5
#
#                                             geometry
# 0  MULTIPOLYGON (((240464.507 337879.568, 240453....
# 1  MULTIPOLYGON (((240197.444 337344.925, 240189....
# 2  MULTIPOLYGON (((239477.407 340615.713, 239466....
# 3  MULTIPOLYGON (((229886.887 340635.928, 229863....
# 4  MULTIPOLYGON (((229630.803 340477.034, 229679....

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.to_file(f"{file_path}/{file_name}2.shp", engine = 'pyogrio')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File c:\python\Lib\site-packages\pyogrio\_err.pyx:240, in pyogrio._err.error_handler()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xeb in position 61: invalid continuation byte
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 gdf.to_file(f"{file_path}/{file_name}2.shp", engine = 'pyogrio')
#
# File c:\python\Lib\site-packages\geopandas\geodataframe.py:1536, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1441 """Write the ``GeoDataFrame`` to a file.
#    1442
#    1443 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1532
#    1533 """
#    1534 from geopandas.io.file import _to_file
# ...

# %%
gdf.to_file(f"{file_path}/{file_name}2.geojson", driver="GeoJSON")
