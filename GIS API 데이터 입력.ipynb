# %%
import pandas as pd
import numpy as np
import requests

# %%
import requests

# API Key
key = '837934A9-32BC-3AF5-8D78-5E3F26CD0700'

# API URL
url = 'https://api.vworld.kr/req/data?'

# 요청할 데이터 및 필터
params = {
    'key': key,
    'request': 'GetFeature',  # 요청 타입 예시
    'service': 'data',         # 서비스 타입 예시
    'size': '1000',               # 페이지당 결과 수 예시
    'geomFilter': 'POINT(129 36))',  # 지리적 필터 (적절한 값으로 대체 필요)
    'data': 'LT_C_GIMSSCS'
}

# 헤더 설정
headers = {
    'data': 'LT_C_GIMSSCS',  # 적절한 데이터 값으로 대체 필요
    'geomFilter': 'POINT(139 36)',  # 지리적 필터 (적절한 값으로 대체 필요)
    'key': key,
    'request': 'GetFeature',
    'service': 'data',
    'size': '1000'  # 요청 크기 설정
}

# GET 요청 보내기
response = requests.get(url, headers=headers, params=params)

# 응답 확인
print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
url
# Out:
# 'https://api.vworld.kr/req/data?'

# %%
data = response.json()['result']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data = response.json()['result']
#
# KeyError: 'result'

# %%
df = pd.DataFrame(data)
# Out:
# []
